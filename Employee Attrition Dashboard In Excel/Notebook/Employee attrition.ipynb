# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("employee_attrition_dataset.xlsx")

# Department distribution
dept_counts = df['Department'].value_counts()

dept_counts.plot(kind='bar')
plt.title("Employees by Department")
plt.show()
